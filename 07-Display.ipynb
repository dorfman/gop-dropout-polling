# %% [markdown]
# # Display
# Show how polling changes when a Republican candidate suspends their campaign for the presidential nomination. Only examined candidates that dropped out during primary season.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import numpy as np
import pandas as pd
import os
from IPython.display import display, HTML
import stats
import analysis

# %% [markdown]
# ## Read Written Files
#
# ### bootPolls.csv
# Downloaded as a CSV from [Huffington Post's Pollster](http://elections.huffingtonpost.com/pollster/2016-national-gop-primary). More info on cleaning polling data in [02-DataCleaning.ipynb](https://github.com/dorfman/gop-dropout-polling/blob/master/02-DataCleaning.ipynb) and [03-Exploration.ipynb](https://github.com/dorfman/gop-dropout-polling/blob/master/03-Exploration.ipynb).
#
# ### candidates.csv
# Manually made dictionary using data (from [Wikipedia](https://en.wikipedia.org/wiki/United_States_presidential_election,_2016#Withdrawn_candidates_2
# )) on when candidates dropped out.
#
# ### PollingBeforeDrop.csv and PollingAfterDrop.csv
# Create two DataFrames indexed by the candidates that dropped out of the race during the primaries. Each column in PollingBeforeDrop holds other candidates' average polling numbers in the week prior to a candidate's campaign suspension. Each cell contains the polling for a candidate in the column the week before the candidate in the row dropped out. Each column in PollingAfterDrop holds other candidates' average polling numbers in the week after a candidate suspends their campaign. Each cell contains the polling for a candidate in the column the week after the candidate in the row dropped out. The average is weighted heavier towards days further away from the date of suspension. More info on these DataFrames in [04-Modeling.ipynb](https://github.com/dorfman/gop-dropout-polling/blob/master//04-Modeling.ipynb).

# %%
polls = analysis.CleanPolls()
candidates = analysis.GetDropData()
PollingBeforeDrop = analysis.GetBeforeData()
PollingAfterDrop = analysis.GetAfterData()
PollingDiff = PollingAfterDrop - PollingBeforeDrop
statFrame = analysis.GetStats(PollingBeforeDrop, PollingAfterDrop, PollingDiff)
pollList = analysis.GenPollSnippets(polls, candidates)

# %% [markdown]
# ## Graphs

# %% [markdown]
# ### Mike Huckabee Suspends His Campaign

# %%
stats.PlotChart(candidates, pollList[5]['poll'], 'Huckabee')

# %%
analysis.PlotPolling('Huckabee', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-02-01</h4>
# Rubio gained 3.72 percentage points in polling, or 59.57% of all polling gains, going up from 11.39 to 15.11
# after Huckabee suspended his campaign giving up 1.74 polling percentage and other candidates lost a cumulative 4.50.

# %% [markdown]
# ### Rand Paul and Rick Santorum Suspend Their Campaigns

# %%
stats.PlotChart(candidates, pollList[8]['poll'], 'Santorum')

# %%
analysis.PlotPolling('Santorum', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-02-03</h4>
# Cruz gained 1.84 percentage points in polling, or 32.84% of all polling gains, going up from 17.88 to 19.72
# after Santorum suspended his campaign giving up 0.66 polling percentage and other candidates lost a cumulative 4.94.

# %% [markdown]
# ### Chris Christie and Carly Fiorina Suspend Their Campaigns

# %%
stats.PlotChart(candidates, pollList[2]['poll'], 'Christie')

# %%
analysis.PlotPolling('Christie', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-02-10</h4>
# Kasich gained 2.79 percentage points in polling, or 38.33% of all polling gains, going up from 4.44 to 7.23
# after Christie suspended his campaign giving up 2.45 polling percentage and other candidates lost a cumulative 4.83.

# %% [markdown]
# ### Jim Gilmore Suspends His Campaign

# %%
stats.PlotChart(candidates, pollList[4]['poll'], 'Gilmore')

# %%
analysis.PlotPolling('Gilmore', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-02-12</h4>
# Kasich gained 3.15 percentage points in polling, or 77.24% of all polling gains, going up from 4.22 to 7.37
# after Gilmore suspended his campaign giving up 0.02 polling percentage and other candidates lost a cumulative 4.06.

# %% [markdown]
# ### Jeb Bush Suspends His Campaign

# %%
stats.PlotChart(candidates, pollList[0]['poll'], 'Bush')

# %%
analysis.PlotPolling('Bush', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-02-16</h4>
# Kasich gained 2.38 percentage points in polling, or 30.33% of all polling gains, going up from 6.03 to 8.41
# Rubio gained 2.14 percentage points in polling, or 32.97% of all polling gains, going up from 13.08 to 15.22
# Undecided gained 1.97 percentage points in polling, or 36.59% of all polling gains, going up from 10.28 to 12.26
# after Bush suspended his campaign giving up 5.03 polling percentage and other candidates lost a cumulative 1.47.

# %% [markdown]
# ### Ben Carson Suspends His Campaign
# It doesn't look like Carson's endorsement of Trump helped Trump noticeably.

# %%
stats.PlotChart(candidates, pollList[1]['poll'], 'Carson')

# %%
analysis.PlotPolling('Carson', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-03-04</h4>
# Cruz gained 3.83 percentage points in polling, or 30.39% of all polling gains, going up from 18.05 to 21.88
# after Carson suspended his campaign giving up 7.95 polling percentage and other candidates lost a cumulative 4.63.

# %% [markdown]
# ### Marco Rubio Suspends His Campaign

# %%
stats.PlotChart(candidates, pollList[7]['poll'], 'Rubio')

# %%
analysis.PlotPolling('Rubio', candidates, statFrame, PollingBeforeDrop, PollingAfterDrop, PollingDiff)
# Out:
# <h4>2016-03-15</h4>
# Cruz gained 4.11 percentage points in polling, or 32.85% of all polling gains, going up from 22.00 to 26.11
# Kasich gained 4.51 percentage points in polling, or 35.14% of all polling gains, going up from 9.93 to 14.44
# Undecided gained 4.22 percentage points in polling, or 32.01% of all polling gains, going up from 13.19 to 17.41
# after Rubio suspended his campaign giving up 11.38 polling percentage and other candidates lost a cumulative 1.46.
